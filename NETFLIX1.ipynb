# %%
# lire le fichier csv
import pandas as pd
donnees=pd.read_csv("/home/souad/data-dev/correction-exo/python/PROJET-NETFLIX/netflix_titles.csv", index_col='show_id')
donnees.head()
# Out:
#              type                                    title  \
# show_id
# 81145628    Movie  Norm of the North: King Sized Adventure
# 80117401    Movie               Jandino: Whatever it Takes
# 70234439  TV Show                       Transformers Prime
# 80058654  TV Show         Transformers: Robots in Disguise
# 80125979    Movie                             #realityhigh
#
#                           director  \
# show_id
# 81145628  Richard Finn, Tim Maltby
# 80117401                       NaN
# 70234439                       NaN
# 80058654                       NaN
# 80125979          Fernando Lebrija
#
#                                                        cast  \
# show_id
# 81145628  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 80117401                                   Jandino Asporaat
# 70234439  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 80058654  Will Friedle, Darren Criss, Constance Zimmer, ...
# ...

# %%
#Afficher les dimensions du dataframe
donnees.shape
# Out:
# (6234, 11)

# %%
#. Compter les films et les séries
#donnees['type'].value_counts()
nbreMovies=donnees.loc[donnees['type']=='Movies'].type.value_counts()
print(nbreMovies)
# Out:
# Series([], Name: type, dtype: int64)

# %%
#Générer le résumé statistique du dataframe
donnees.describe(include='all')
# Out:
#          type title                director                cast  \
# count    6234  6234                    4265                5664
# unique      2  6172                    3301                5469
# top     Movie  Love  Raúl Campos, Jan Suter  David Attenborough
# freq     4265     3                      18                  18
# mean      NaN   NaN                     NaN                 NaN
# std       NaN   NaN                     NaN                 NaN
# min       NaN   NaN                     NaN                 NaN
# 25%       NaN   NaN                     NaN                 NaN
# 50%       NaN   NaN                     NaN                 NaN
# 75%       NaN   NaN                     NaN                 NaN
# max       NaN   NaN                     NaN                 NaN
#
#               country       date_added  release_year rating  duration  \
# count            5758             6223    6234.00000   6224      6234
# ...

# %%
#Compter les valeurs manquantes
donnees.isna()
# Out:
#            type  title  director   cast  country  date_added  release_year  \
# show_id
# 81145628  False  False     False  False    False       False         False
# 80117401  False  False      True  False    False       False         False
# 70234439  False  False      True  False    False       False         False
# 80058654  False  False      True  False    False       False         False
# 80125979  False  False     False  False    False       False         False
# ...         ...    ...       ...    ...      ...         ...           ...
# 80000063  False  False      True  False    False        True         False
# 70286564  False  False      True  False    False        True         False
# 80116008  False  False      True   True     True        True         False
# 70281022  False  False      True  False    False        True         False
# 70153404  False  False      True  False    False        True         False
#
#           rating  duration  listed_in  description
# ...

# %%
#Compter les valeurs manquantes
donnees.isna().sum()
# Out:
# type               0
# title              0
# director        1969
# cast             570
# country          476
# date_added        11
# release_year       0
# rating            10
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
#Explorer les valeurs manquantes
director=donnees.loc[donnees['director'].isna()]
print(director.type.value_counts())
# Out:
# TV Show    1841
# Movie       128
# Name: type, dtype: int64

# %%
#Explorer les valeurs manquantes
donnees1=donnees.loc[donnees['director'].isna(),:]
donnees1
# Out:
#              type                                        title director  \
# show_id
# 80117401    Movie                   Jandino: Whatever it Takes      NaN
# 70234439  TV Show                           Transformers Prime      NaN
# 80058654  TV Show             Transformers: Robots in Disguise      NaN
# 80163890  TV Show                                      Apaches      NaN
# 80117902  TV Show                                 Fire Chasers      NaN
# ...           ...                                          ...      ...
# 80000063  TV Show                                 Red vs. Blue      NaN
# 70286564  TV Show                                        Maron      NaN
# 80116008    Movie       Little Baby Bum: Nursery Rhyme Friends      NaN
# 70281022  TV Show  A Young Doctor's Notebook and Other Stories      NaN
# 70153404  TV Show                                      Friends      NaN
#
#                                                        cast         country  \
# show_id
# ...

# %%
donnees1['type'].value_counts()
# Out:
# TV Show    1841
# Movie       128
# Name: type, dtype: int64

# %%
donnees2=donnees.loc[donnees['cast'].isna()]
donnees2
# Out:
#              type                                             title  \
# show_id
# 80117902  TV Show                                      Fire Chasers
# 80046727    Movie                                    Rolling Papers
# 80203094    Movie                                       City of Joy
# 80190843  TV Show                                    First and Last
# 81011682  TV Show  Christiane Amanpour: Sex & Love Around the World
# ...           ...                                               ...
# 80036747  TV Show                       Pororo - The Little Penguin
# 80190407  TV Show                                 Murderous Affairs
# 80231523  TV Show                               The Minimighty Kids
# 80049872  TV Show                                           Chelsea
# 80116008    Movie            Little Baby Bum: Nursery Rhyme Friends
#
#                  director cast                 country          date_added  \
# show_id
# ...

# %%
#affichage des 10 premieres lignes 
donnees3=donnees2['listed_in'].value_counts()
donnees3[0:10]
# Out:
# Documentaries                                         148
# Documentaries, International Movies                    94
# Docuseries                                             31
# Documentaries, Sports Movies                           20
# Crime TV Shows, Docuseries                             19
# Documentaries, Music & Musicals                        15
# Documentaries, International Movies, Sports Movies     14
# Kids' TV                                               14
# Docuseries, International TV Shows                     14
# Crime TV Shows, Docuseries, International TV Shows     12
# Name: listed_in, dtype: int64

# %%
#supprimer les lignes dupliquées
donnees.duplicated().value_counts()
# Out:
# False    6233
# True        1
# dtype: int64

# %%
#afficher le dataframe sans les lignes dupliquées
donnees_drop=donnees.drop_duplicates()
donnees_drop
# Out:
#              type                                        title  \
# show_id
# 81145628    Movie      Norm of the North: King Sized Adventure
# 80117401    Movie                   Jandino: Whatever it Takes
# 70234439  TV Show                           Transformers Prime
# 80058654  TV Show             Transformers: Robots in Disguise
# 80125979    Movie                                 #realityhigh
# ...           ...                                          ...
# 80000063  TV Show                                 Red vs. Blue
# 70286564  TV Show                                        Maron
# 80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 70153404  TV Show                                      Friends
#
#                           director  \
# show_id
# 81145628  Richard Finn, Tim Maltby
# 80117401                       NaN
# 70234439                       NaN
# 80058654                       NaN
# ...

# %%
#Compter les films/séries produits par les États-Unis et par la France

donnees.loc[donnees['country'].isin(['France','United States']),:].shape[0]
# Out:
# 2122

# %%
#le contenu le plus vieux disponible
#donnees2=donnees.loc[donnees['cast'].isna()]
donnees5=donnees.loc[donnees['release_year']==donnees['release_year'].min(), ['title','release_year']]
donnees5
# Out:
#                                       title  release_year
# show_id
# 81030762  Pioneers: First Women Filmmakers*          1925

# %%
# Afficher le film avec la durée la plus longue sur Netflix
donnees6=donnees.loc[donnees['type']=='Movie']
donnees6
# Out:
#            type                                    title  \
# show_id
# 81145628  Movie  Norm of the North: King Sized Adventure
# 80117401  Movie               Jandino: Whatever it Takes
# 80125979  Movie                             #realityhigh
# 70304989  Movie                                 Automata
# 80164077  Movie       Fabrizio Copano: Solo pienso en mi
# ...         ...                                      ...
# 80085438  Movie                          Frank and Cindy
# 80085439  Movie                          Frank and Cindy
# 80011846  Movie                                  Iverson
# 80064521  Movie      Jeremy Scott: The People's Designer
# 80116008  Movie   Little Baby Bum: Nursery Rhyme Friends
#
#                                  director  \
# show_id
# 81145628         Richard Finn, Tim Maltby
# 80117401                              NaN
# 80125979                 Fernando Lebrija
# 70304989                      Gabe Ibáñez
# 80164077  Rodrigo Toro, Francisco Schultz
# ...

# %%
donnees['duration']=pd.Series(donnees6['duration']).str.replace("min", "").astype(int)
donnees
# Out:
#              type                                        title  \
# show_id
# 81145628    Movie      Norm of the North: King Sized Adventure
# 80117401    Movie                   Jandino: Whatever it Takes
# 70234439  TV Show                           Transformers Prime
# 80058654  TV Show             Transformers: Robots in Disguise
# 80125979    Movie                                 #realityhigh
# ...           ...                                          ...
# 80000063  TV Show                                 Red vs. Blue
# 70286564  TV Show                                        Maron
# 80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 70153404  TV Show                                      Friends
#
#                           director  \
# show_id
# 81145628  Richard Finn, Tim Maltby
# 80117401                       NaN
# 70234439                       NaN
# 80058654                       NaN
# ...

# %% [markdown]
# ###

# %%
#11
categories=pd.Series(", ".join(donnees["listed_in"].dropna()).split(", "))

categories.value_counts()
#
# Out:
# International Movies            1927
# Dramas                          1623
# Comedies                        1113
# International TV Shows          1001
# Documentaries                    668
# TV Dramas                        599
# Action & Adventure               597
# Independent Movies               552
# TV Comedies                      436
# Thrillers                        392
# Children & Family Movies         378
# Romantic Movies                  376
# Crime TV Shows                   363
# Kids' TV                         328
# Stand-Up Comedy                  281
# Docuseries                       279
# Romantic TV Shows                278
# Horror Movies                    262
# Music & Musicals                 243
# British TV Shows                 210
# Sci-Fi & Fantasy                 193
# Sports Movies                    157
# Reality TV                       153
# Korean TV Shows                  132
# TV Action & Adventure            126
# ...

# %%
#CORRECTION raphael
#8. Compter les films/séries produits par les États-Unis et par la France
data_film_usa = donnees.loc[donnees.country == 'United States', 'title']
data_film_fr = donnees.loc[donnees.country == 'France', 'title']
print(data_film_usa.shape[0])
# Out:
# 2032

# %%
#9. Afficher le contenu le plus vieux disponible sur Netflix
data_older = donnees.loc[donnees.release_year == donnees.release_year.min(), ['title', 'release_year']]
print(data_older)
# Out:
#                                       title  release_year
# show_id
# 81030762  Pioneers: First Women Filmmakers*          1925

# %%
#10. Afficher le film avec la durée la plus longue sur Netflix
#Afficher les 5 films les + long(juste la durée)
data_movies = donnees.loc[donnees.type == 'Movie']
duree = pd.Series(data_movies['duration']).str.replace(" min", "").astype('int')
print(duree)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-f81624ce0ee2> in <module>
#       2 #Afficher les 5 films les + long(juste la durée)
#       3 data_movies = donnees.loc[donnees.type == 'Movie']
# ----> 4 duree = pd.Series(data_movies['duration']).str.replace(" min", "").astype('int')
#       5 print(duree)
#       6
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# -> 5270             return object.__getattribute__(self, name)
#    5271         else:
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
# ...

# %%
#Affiche les 5 films avec toutes les infos(version merge & series)
data_movies = donnees.loc[donnees.type == 'Movie']
duree = pd.Series(data_movies['duration']).str.replace("min", "").astype('int').sort_values(ascending=False).head(5)
print(duree)
data_merged = pd.merge(donnees, duree.to_frame(), on='show_id', how='inner')
data_merged
data_film_duration = data_merged.sort_values(by='duration_y', ascending=False).head(5)[["title", "duration_x"]]
print(data_film_duration)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-6178845e12da> in <module>
#       1 #Affiche les 5 films avec toutes les infos(version merge & series)
#       2 data_movies = donnees.loc[donnees.type == 'Movie']
# ----> 3 duree = pd.Series(data_movies['duration']).str.replace("min", "").astype('int').sort_values(ascending=False).head(5)
#       4 print(duree)
#       5 data_merged = pd.merge(donnees, duree.to_frame(), on='show_id', how='inner')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# -> 5270             return object.__getattribute__(self, name)
#    5271         else:
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ...

# %%
#Affiche les 5 films avec toutes les infos
donnees["duration"] = pd.Series(data_movies['duration']).str.replace(" min", "").astype('int').sort_values(ascending=False).head(5)

data_film_duration_2 = donnees.sort_values(by='duration', ascending=False).head(5)
data_film_duration_2
# Out:
#            type                       title            director  \
# show_id
# 80988062  Movie  Black Mirror: Bandersnatch                 NaN
# 60002818  Movie                      Sangam          Raj Kapoor
# 60020906  Movie                      Lagaan  Ashutosh Gowariker
# 70090035  Movie                Jodhaa Akbar  Ashutosh Gowariker
# 80175798  Movie                The Irishman     Martin Scorsese
#
#                                                        cast        country  \
# show_id
# 80988062  Fionn Whitehead, Will Poulter, Craig Parkinson...  United States
# 60002818  Raj Kapoor, Vyjayanthimala, Rajendra Kumar, La...          India
# 60020906  Aamir Khan, Gracy Singh, Rachel Shelley, Paul ...          India
# 70090035  Hrithik Roshan, Aishwarya Rai Bachchan, Sonu S...          India
# 80175798  Robert De Niro, Al Pacino, Joe Pesci, Harvey K...  United States
#
#                  date_added  release_year rating  duration  \
# show_id
# ...

# %%
#Affiche les 5 films avec toutes les infos
donnees["duration"] = pd.Series(data_movies['duration']).str.replace(" min", "").astype('int')
data_film_duration_2 = donnees.sort_values(by='duration', ascending=False).head(5)[["title", "duration"]]
print(data_film_duration_2)
# Out:
#                                title  duration
# show_id
# 80988062  Black Mirror: Bandersnatch     312.0
# 60002818                      Sangam     228.0
# 60020906                      Lagaan     224.0
# 70090035                Jodhaa Akbar     214.0
# 80175798                The Irishman     209.0
